# %% [markdown]
# Title: Random Forest Regressor for Property Prediction
# =======
# - Created: 2019.10.03
# - Updated: 2019.10.21
# - Author: Kyung Min, Lee
#
# Learned from
# - "Chapter 2 of Hands-on Machine Learning Book"
# - Sckit-Learn documents

# %% [markdown]
# ## A random forest is a meta estimator that fits a number of classifying decision trees on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting. The sub-sample size is always the same as the original input sample size but the samples are drawn with replacement if bootstrap=True (default).
#
# > class sklearn.ensemble.RandomForestRegressor(n_estimators=’warn’, criterion=’mse’, max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False)[source]

# %% [markdown]
# HyperParameters
# ---

# %% [markdown]
# - **n_estimators**[integer, optional (default=10)]: The number of trees in the forest.
#   - Changed in version 0.20: The default value of n_estimators will change from 10 in version 0.20 to 100 in version 0.22.
#
# - **criterion**[string, optional (default=”mse”)]: The function to measure the quality of a split.
#   - Supported criteria are “mse” for the mean squared error, which is equal to variance reduction as feature selection criterion, and “mae” for the mean absolute error.
#
# - **max_depth**[integer or None, optional (default=None)]: The maximum depth of the tree.
#   - If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples.
#
# - **min_samples_split**[int, float, optional (default=2)]: The minimum number of samples required to split an internal node:
#   - If int, then consider min_samples_split as the minimum number.
#   - If float, then min_samples_split is a fraction and ceil(min_samples_split * n_samples) are the minimum number of samples for each split.
#
# - **min_samples_leaf**[int, float, optional (default=1)]: The minimum number of samples required to be at a leaf node.
#   - A split point at any depth will only be considered if it leaves at least min_samples_leaf training samples in each of the left and right branches. <u>This may have the effect of smoothing the model, especially in regression.</u>
#   - If int, then consider min_samples_leaf as the minimum number.
#   - If float, then min_samples_leaf is a fraction and ceil(min_samples_leaf * n_samples) are the minimum number of samples for each node.
#
# - **min_weight_fraction_leaf**[float, optional (default=0.)]
#   - The minimum weighted fraction of the sum total of weights (of all the input samples) required to be at a leaf node.
#   - Samples have equal weight when sample_weight is not provided.
#
# - **max_features**[int, float, string or None, optional (default=”auto”)]: The number of features to consider when looking for the best split:
#   - If int, then consider max_features features at each split.
#   - If float, then max_features is a fraction and int(max_features * n_features) features are considered at each split.
#   - If “auto”, then max_features=n_features.
#   - If “sqrt”, then max_features=sqrt(n_features).
#   - If “log2”, then max_features=log2(n_features).
#   - If None, then max_features=n_features.
# Note: the search for a split does not stop until at least one valid partition of the node samples is found, even if it requires to effectively inspect more than max_features features.
#
# - **max_leaf_nodes**[int or None, optional (default=None)]: Grow trees with max_leaf_nodes in best-first fashion.
#   - Best nodes are defined as relative reduction in impurity. If None then unlimited number of leaf nodes.
#
# - **min_impurity_decrease**[float, optional (default=0.)]: A node will be split if this split induces a decrease of the impurity greater than or equal to this value.
#   - The weighted impurity decrease equation is the following: (Node importance using Gini Importace)
#   ![gini_imp](https://miro.medium.com/max/757/1*mcHzG8OjhQ2ryiBH7MBPUA.png)
#   ![gini_imp1](https://miro.medium.com/max/1498/1*uAGS042OxMJ4Ic3k4s313Q.png)
#   ![gini_imp2](https://miro.medium.com/max/2829/1*gdMrk7yEPJLio0d0Sixtkg.png)
#   ![gini_imp3](https://miro.medium.com/max/1634/1*C-bkgMBs4drNVyBb1VJcEQ.png)
#
# - **bootstrap**[boolean, optional (default=True)]: Whether bootstrap samples are used when building trees. If False, the whole datset is used to build each tree.
#
# - **oob_score**[bool, optional (default=False)]: whether to use out-of-bag samples to estimate the R^2 on unseen data.
#
# - **n_jobs**[int or None, optional (default=None)]: The number of jobs to run in parallel for both fit and predict.
#   - None` means 1 unless in a joblib.parallel_backend context. -1 means using all processors. See Glossary for more details.
#
# - **random_state**[int, RandomState instance or None, optional (default=None)]
# If int, random_state is the seed used by the random number generator; If RandomState instance, random_state is the random number generator; If None, the random number generator is the RandomState instance used by np.random.
#
# - **verbose**[int, optional (default=0)]: Controls the verbosity when fitting and predicting.
#
# - **warm_start**[bool, optional (default=False)]: When set to True, reuse the solution of the previous call to fit and add more estimators to the ensemble, otherwise, just fit a whole new forest.

# %% [markdown]
# Explanation of Random Forest's Main Parameters
# ---
#
# random forest model에서 주요 parameter는
#
# n_estimators : 생성할 tree의 개수와
#
# max_features : 최대 선택할 특성의 수입니다.
#
# random forest는 기본적으로 bootstrap sampling(복원추출)을 사용하며 decision tree 생성으로 algorithm으로 진행합니다.
#
# bootstrap sampling에서 어떤 데이터 포인트는 약 36.6%정도 누락될 확률이 존재하는데
# 이 것은 다음과정으로 확인할 수 있습니다.
#
#  - 100개의 표본중 표본 하나가 선택되지 않을 확률은 99/100
#  - 뽑은 표본을 제외하지 않고 100번 반복할 때 한번도 선택되지 않을 확률: (0.99)^100 = 0.366
#
#
#
# n_estimators에서bootstrap sampling은 random forest의 tree가 조금씩 다른 데이터셋으로 만들어지도록합니다. max_feature에서 각 node는 특성의 일부를 무작위로 추출하여 사용합니다.
# max_features를 전체 특성의수로 설정하면 모든 특성을 고려하므로 decision tree에서 무작위성이 들어가지 않습니다.
#
# 그러나 bootstrap sampling의 무작위성은 존재합니다.
#
# max_features 값을 크게 하면 random forest의 tree들은 같은 특성을 고려하므로 tree들이 매우 비슷해지고 가장 두드러진 특성을 이용해 데이터에 잘 맞춰집니다.
#
# max_features를 낮추면 random forest tree들은 많이 달라지고 각 tree는 데이터에 맞추기 위해 tree의 깊이가 깊어집니다.
#
# 출처: https://woolulu.tistory.com/28

# %% [markdown]
# Attributes
# ---

# %% [markdown]
# - **estimators_**[list of DecisionTreeRegressor]: The collection of fitted sub-estimators.
#
# - **feature_importances_**[array of shape = [n_features]] :Return the feature importances (the higher, the more important the feature).
#
# - **n_features_**[int]: The number of features when fit is performed.
#
# - **n_outputs_**[int]: The number of outputs when fit is performed.
#
# - **oob_score_**[float]: Score of the training dataset obtained using an out-of-bag estimate.
#
# - **oob_prediction_**[array of shape = [n_samples]]: Prediction computed with out-of-bag estimate on the training set.

# %% [markdown]
# Setup
# ---

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn

# Common imports
import numpy as np
import os

# Pandas
import pandas as pd

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)


def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %%
sklearn.__version__
# Out:
# '0.21.1'

# %% [markdown]
# Get the data
# ============

# %%
from google.colab import files
uploaded=files.upload()

for fn in uploaded.keys():
  print('User uploaded file"{name}" with length{length} bytes'.format(
      name = fn, length=len(uploaded[fn])
  ))
# Out:
#      <input type="file" id="files-c032a26e-eae5-48f0-be24-54cb2e1b2b0b" name="files[]" multiple disabled />
#      <output id="result-c032a26e-eae5-48f0-be24-54cb2e1b2b0b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 3MA_data.csv to 3MA_data.csv
# User uploaded file"3MA_data.csv" with length21539 bytes

# %%
from google.colab import drive

drive.mount('/content/gdrive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd

df = pd.read_csv("3MA_data.csv")
df.head()
# Out:
#    yield stress  elongation  1k_voltage     1k_RE     1k_IM  UTS(no)  \
# 0    193.928416    0.000000    2.247535  7.353994 -0.617027    412.0
# 1    193.928416    7.832161    2.249186  7.330924 -0.934697    412.0
# 2    193.928416    7.825444    2.248753  7.367316 -0.574723    412.0
# 3    193.928416    7.813692    2.249833  7.345533 -0.862965    412.0
# 4    193.928416    7.780144    2.247326  7.350974 -0.681030    412.0
#
#       5k_RE     5k_IM  5k_time  5k_voltage
# 0  8.103753  0.048710      0.0    5.330770
# 1  8.084683  0.057399      3.2    5.329357
# 2  8.099559  0.125401      6.4    5.331381
# 3  8.103011  0.153286      9.6    5.329095
# 4  8.122078  0.185302     12.8    5.333564

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 10 columns):
# yield stress    203 non-null float64
# elongation      204 non-null float64
# 1k_voltage      209 non-null float64
# 1k_RE           209 non-null float64
# 1k_IM           209 non-null float64
# UTS(no)         204 non-null float64
# 5k_RE           190 non-null float64
# 5k_IM           190 non-null float64
# 5k_time         190 non-null float64
# 5k_voltage      190 non-null float64
# dtypes: float64(10)
# memory usage: 16.4 KB

# %% [markdown]
# 2 Variable (1k_RE & 1k_IM) data
# ---

# %%
df = df.loc[:,["yield stress", "elongation", "1k_RE", "1k_IM"]]
df = df.drop(df.index[190:209])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 189
# Data columns (total 4 columns):
# yield stress    190 non-null float64
# elongation      190 non-null float64
# 1k_RE           190 non-null float64
# 1k_IM           190 non-null float64
# dtypes: float64(4)
# memory usage: 7.4 KB

# %% [markdown]
# 6 Variable (1k_voltage, 1k_RE, 1k_IM, 5k_voltage, 5k_RE, 5k_Im) data
# ---

# %%
df = df.loc[:,["yield stress", "elongation","1k_voltage", "1k_RE", "1k_IM", "5k_voltage", "5k_RE", "5k_IM"]]
df = df.drop(df.index[190:209])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 189
# Data columns (total 8 columns):
# yield stress    190 non-null float64
# elongation      190 non-null float64
# 1k_voltage      190 non-null float64
# 1k_RE           190 non-null float64
# 1k_IM           190 non-null float64
# 5k_voltage      190 non-null float64
# 5k_RE           190 non-null float64
# 5k_IM           190 non-null float64
# dtypes: float64(8)
# memory usage: 13.4 KB

# %%
df.describe()
# Out:
#        yield stress  elongation  1k_voltage       1k_RE       1k_IM  \
# count    190.000000  190.000000  190.000000  190.000000  190.000000
# mean     331.194462    5.071727    2.200824    7.184671   -0.994367
# std       60.202631    1.598025    0.022435    0.078204    0.122292
# min      193.928416    0.000000    2.173205    7.076378   -1.220670
# 25%      294.251701    3.747314    2.181697    7.121649   -1.065305
# 50%      346.269052    5.080847    2.193432    7.162842   -1.015719
# 75%      380.555745    6.401437    2.217603    7.245272   -0.922856
# max      406.890446    7.832161    2.250206    7.367316   -0.574723
#
#        5k_voltage       5k_RE       5k_IM
# count  190.000000  190.000000  190.000000
# mean     5.312965    8.076179    0.057261
# std      0.005074    0.012742    0.093277
# min      5.304340    8.045659   -0.305125
# 25%      5.309558    8.068358    0.011753
# 50%      5.312546    8.075137    0.058024
# 75%      5.315220    8.084260    0.108549
# max      5.333564    8.122078    0.389185

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000028E5E8E2550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028E5E94E978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028E5E972CC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000028E5E9A3278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028E5E9C97B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028E5E9F0D30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000028E5EA212B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028E5EA48860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028E5EA48898>]],
#       dtype=object)

# %%
# to make this notebook's output identical at every run
np.random.seed(42)

# %%
# train, test data split
from sklearn.model_selection import train_test_split

X = df.loc[:,["1k_voltage", "1k_RE", "1k_IM", "5k_voltage", "5k_RE", "5k_IM"]]
ys = df.loc[:,"yield stress"]
elong = df.loc[:,"elongation"]

X_train, X_test, ys_train, ys_test = train_test_split(X, ys, test_size=0.2, random_state=42)
X_train, X_test, el_train, el_test = train_test_split(X, elong, test_size=0.2, random_state=42)
len(X_train)
# Out:
# 152

# %%
len(X_test)
# Out:
# 38

# %%
#X_train.to_csv("X_train.csv", mode='w')

# %% [markdown]
# Discover and visualize the data to gain insights
# ===

# %%
# Copy the dataset in order not to harm train set
df_copy = df.copy()
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 189
# Data columns (total 8 columns):
# yield stress    190 non-null float64
# elongation      190 non-null float64
# 1k_voltage      190 non-null float64
# 1k_RE           190 non-null float64
# 1k_IM           190 non-null float64
# 5k_voltage      190 non-null float64
# 5k_RE           190 non-null float64
# 5k_IM           190 non-null float64
# dtypes: float64(8)
# memory usage: 13.4 KB

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 51 to 102
# Data columns (total 6 columns):
# 1k_voltage    152 non-null float64
# 1k_RE         152 non-null float64
# 1k_IM         152 non-null float64
# 5k_voltage    152 non-null float64
# 5k_RE         152 non-null float64
# 5k_IM         152 non-null float64
# dtypes: float64(6)
# memory usage: 8.3 KB

# %%
df_copy.plot(kind="scatter", x="1k_RE", y="yield stress")

# %%
df_copy.plot(kind="scatter", x="1k_IM", y="yield stress")

# %%
# Analysis of Standard correlation coefficient
corr_matrix = df_copy.corr()
corr_matrix
# Out:
#               yield stress  elongation  1k_voltage     1k_RE     1k_IM  \
# yield stress      1.000000   -0.886806   -0.994657 -0.980480 -0.732689
# elongation       -0.886806    1.000000    0.897797  0.883247  0.591942
# 1k_voltage       -0.994657    0.897797    1.000000  0.987401  0.736476
# 1k_RE            -0.980480    0.883247    0.987401  1.000000  0.816920
# 1k_IM            -0.732689    0.591942    0.736476  0.816920  1.000000
# 5k_voltage       -0.581111    0.294499    0.557735  0.539938  0.477172
# 5k_RE            -0.441823    0.290037    0.421207  0.405007  0.310078
# 5k_IM            -0.082548    0.053422    0.079463  0.075760  0.035729
#
#               5k_voltage     5k_RE     5k_IM
# yield stress   -0.581111 -0.441823 -0.082548
# elongation      0.294499  0.290037  0.053422
# 1k_voltage      0.557735  0.421207  0.079463
# 1k_RE           0.539938  0.405007  0.075760
# 1k_IM           0.477172  0.310078  0.035729
# 5k_voltage      1.000000  0.596119  0.079823
# 5k_RE           0.596119  1.000000  0.081091
# 5k_IM           0.079823  0.081091  1.000000

# %%
# Check what affects the most for the yield stress
corr_matrix["yield stress"].sort_values(ascending=False)


# 1kHz_voltage > 1k_RE > 1k_IM
# Out:
# yield stress    1.000000
# 5k_IM          -0.082548
# 5k_RE          -0.441823
# 5k_voltage     -0.581111
# 1k_IM          -0.732689
# elongation     -0.886806
# 1k_RE          -0.980480
# 1k_voltage     -0.994657
# Name: yield stress, dtype: float64

# %%
corr_matrix["elongation"].sort_values(ascending=False)
# Out:
# elongation      1.000000
# 1k_voltage      0.897797
# 1k_RE           0.883247
# 1k_IM           0.591942
# 5k_voltage      0.294499
# 5k_RE           0.290037
# 5k_IM           0.053422
# yield stress   -0.886806
# Name: elongation, dtype: float64

# %%
print(X_train)
# Out:
#      1k_voltage     1k_RE     1k_IM  5k_voltage     5k_RE     5k_IM
# 51     2.215403  7.245305 -0.903072    5.312309  8.068984  0.092698
# 35     2.225431  7.275967 -0.897505    5.312577  8.066472  0.074681
# 118    2.186764  7.151657 -1.049820    5.310293  8.075633  0.080307
# 60     2.210931  7.240860 -0.730820    5.310039  8.070268  0.101880
# 161    2.177262  7.109777 -1.014860    5.316873  8.084991  0.013395
# 76     2.203891  7.221163 -0.808060    5.309615  8.066271  0.082328
# 69     2.206140  7.200744 -0.992840    5.313729  8.077973  0.010207
# 29     2.229327  7.279347 -0.921136    5.315442  8.068980  0.018230
# 128    2.185847  7.134817 -1.039134    5.309051  8.053031  0.052793
# 152    2.179460  7.086552 -1.190011    5.314057  8.060679  0.097636
# 165    2.177385  7.126876 -0.898958    5.315302  8.089053 -0.305125
# 31     2.228250  7.259413 -1.038934    5.314041  8.088805  0.109319
# 153    2.178293  7.102217 -1.044152    5.314748  8.082829  0.090453
# 12     2.240065  7.312785 -0.839329    5.316171  8.076581  0.213202
# 41     2.221358  7.253217 -0.910868    5.314177  8.082277  0.121138
# 178    2.175598  7.100199 -1.030840    5.316091  8.065609  0.230196
# 55     2.213836  7.242638 -0.918922    5.307781  8.086931  0.185933
# 98     2.191654  7.150152 -1.124969    5.309888  8.070790  0.074150
# 93     2.193568  7.147151 -1.074207    5.309254  8.081505  0.033007
# 26     2.231911  7.315852 -0.679348    5.312063  8.073438  0.078466
# 38     2.222884  7.274650 -0.838035    5.313113  8.074716  0.076589
# 117    2.186599  7.141808 -1.019309    5.307195  8.079513  0.206251
# 156    2.178776  7.090221 -1.185599    5.312406  8.066106 -0.126833
# 133    2.183898  7.140395 -1.045984    5.307017  8.074423  0.178887
# 185    2.174771  7.091567 -1.080754    5.311251  8.045659 -0.072490
#
#       5k_IM  5k_voltage     ica_1     ica_2  ...     ica_8       pca_1  \
# 0  0.048710    5.330770 -0.116510 -0.117151  ... -0.075769  330.186138
# 1  0.057399    5.329357  0.786518 -3.171239  ... -0.557662  327.215644
# 2  0.125401    5.331381  0.081439 -4.195743  ... -0.308729  324.177928
# 3  0.153286    5.329095  0.951304 -2.862410  ...  0.559499  321.141359
# 4  0.185302    5.333564 -0.096708 -4.449416  ...  0.295758  318.102756
#
#        pca_2      pca_3     pca_4     pca_5     pca_6     pca_7     pca_8  \
# 0  35.414014  13.629898 -0.042054 -0.067931 -0.026539  0.174546  0.150698
# 1  36.184830  -1.546919  0.264383 -1.961450 -1.454055 -0.901060 -0.069204
# 2  37.222513  -2.131075  0.421728  2.517910 -0.056068  0.758381 -0.524406
# 3  38.188802  -1.392249 -0.649956 -0.864369  0.426757 -1.052226  0.228620
# 4  39.253055  -2.435435 -0.370063  1.345922  1.818258  0.718582 -0.071789
#
#       pca_9
# 0  3.271426
# 1  0.789393
# 2  1.443719
# 3  0.481708
# 4  1.750102
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 189
# Data columns (total 25 columns):
# yield stress    190 non-null float64
# elongation      190 non-null float64
# 1k_voltage      190 non-null float64
# 1k_RE           190 non-null float64
# 1k_IM           190 non-null float64
# 5k_RE           190 non-null float64
# 5k_IM           190 non-null float64
# 5k_voltage      190 non-null float64
# ica_1           190 non-null float64
# ica_2           190 non-null float64
# ica_3           190 non-null float64
# ica_4           190 non-null float64
# ica_5           190 non-null float64
# ica_6           190 non-null float64
# ica_7           190 non-null float64
# ica_8           190 non-null float64
# pca_1           190 non-null float64
# pca_2           190 non-null float64
# pca_3           190 non-null float64
# pca_4           190 non-null float64
# pca_5           190 non-null float64
# pca_6           190 non-null float64
# pca_7           190 non-null float64
# pca_8           190 non-null float64
# pca_9           190 non-null float64
# dtypes: float64(25)
# memory usage: 38.6 KB

# %%
from sklearn.decomposition import PCA, FastICA
pca = PCA()
S_pca_ = pca.fit(df).transform(df)

ica = FastICA()
S_ica_ = ica.fit(df).transform(df)  # Estimate the source

S_ica_ /= S_ica_.std(axis=0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\decomposition\fastica_.py:119: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   ConvergenceWarning)

# %%
print("ica shape: ",S_ica_.shape)
print("pca shape: ",S_pca_.shape)
# Out:
# ica shape:  (190, 25)
# pca shape:  (190, 25)

# %%
S_ica_ = pd.DataFrame(S_ica_)
S_ica_.to_csv("ICA_data.csv", mode ='w')

S_pca_ = pd.DataFrame(S_pca_)
S_pca_.to_csv("PCA_data.csv", mode ='w')

# %%
S_ica_.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001645671BA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001645728D160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001645922A9B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016459243F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000164587914E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000164587B89E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000164587E1F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016458810518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016458810550>]],
#       dtype=object)

# %%
S_pca_ = pd.DataFrame(S_pca_)
S_pca_.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016458E0A320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016458BF3630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000164598E93C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016459904940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001645926DE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001645929D3C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000164592C3940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000164592ECEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00
# 22  3.249712e-05 -0.000012  0.000010  2.390336e-05  1.812391e-05
# 23 -3.978262e-05  0.000010 -0.000011 -2.634106e-05 -1.623133e-05
# 24  4.385334e-05  0.000009 -0.000022  2.496836e-05  1.260565e-05
#
#               21        22        23            24
# 0   2.696715e-07  0.000005  0.000017  1.596390e-06
# 1  -2.194163e-05 -0.000007  0.000015 -1.792619e-05
# 2  -5.741162e-05  0.000031 -0.000036  5.970404e-05
# 3  -1.115073e-05  0.000002 -0.000036  9.314437e-06
# 4  -1.751200e-06  0.000014 -0.000019  4.916551e-08
# 5  -4.075817e-05  0.000002 -0.000074  2.176104e-06
# 6   2.266217e-05 -0.000015  0.000006 -6.034356e-06
# 7   1.723481e-05 -0.000017  0.000029 -2.410667e-05
# 8   6.051193e-05 -0.000009  0.000074 -3.080134e-05
# 9  -5.004048e-05  0.000015 -0.000043  6.589823e-05
# 10  1.932413e-06 -0.000014  0.000002 -1.043139e-05
# 11  4.891943e-05 -0.000036  0.000116 -1.505686e-05
# 12  2.011324e-05 -0.000017  0.000045 -2.268658e-05
# 13 -1.984468e-05 -0.000019 -0.000015 -1.762584e-05
# 14  6.551936e-06 -0.000017  0.000002 -1.897520e-05
# 15 -3.554597e-05  0.000005  0.000005  3.332960e-05
# 16 -2.786582e-05  0.000032 -0.000040  4.385334e-05
# 17 -1.078082e-05 -0.000012  0.000010  9.089528e-06
# 18  1.602689e-05  0.000010 -0.000011 -2.239254e-05
# 19  5.661932e-06  0.000024 -0.000026  2.496836e-05
# 20 -4.185539e-06  0.000018 -0.000016  1.260565e-05
# 21  1.000000e+00 -0.000016  0.000003 -1.911274e-06
# 22 -1.625295e-05  1.000000 -0.000019 -4.482164e-06
# 23  3.264019e-06 -0.000019  1.000000 -1.315724e-05
# 24 -1.911274e-06 -0.000004 -0.000013  1.000000e+00
#
# [25 rows x 25 columns]

# %% [markdown]
# ## Choose ICA & PCA data and add

# %%
df = pd.read_csv("3MA_data+ica+pca.csv")
df = df.drop(df.index[190:209])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 189
# Data columns (total 25 columns):
# yield stress    190 non-null float64
# elongation      190 non-null float64
# 1k_voltage      190 non-null float64
# 1k_RE           190 non-null float64
# 1k_IM           190 non-null float64
# 5k_RE           190 non-null float64
# 5k_IM           190 non-null float64
# 5k_voltage      190 non-null float64
# ica_1           190 non-null float64
# ica_2           190 non-null float64
# ica_3           190 non-null float64
# ica_4           190 non-null float64
# ica_5           190 non-null float64
# ica_6           190 non-null float64
# ica_7           190 non-null float64
# ica_8           190 non-null float64
# pca_1           190 non-null float64
# pca_2           190 non-null float64
# pca_3           190 non-null float64
# pca_4           190 non-null float64
# pca_5           190 non-null float64
# pca_6           190 non-null float64
# pca_7           190 non-null float64
# pca_8           190 non-null float64
# pca_9           190 non-null float64
# dtypes: float64(25)
# memory usage: 38.6 KB

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016462D39C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016462CFA240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016462D184A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016462D05710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016462C80978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016462CA1BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016462CA8E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016462CE9128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016462CE9160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001646525E5C0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016465285828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000164652B0A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000164652D8CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016465300F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000
# ica_6         3.241221e-01 -2.097771e-01
# ica_7        -1.670843e-04 -5.889593e-02
# ica_8         8.409222e-01 -2.167308e-02
# pca_1         1.162242e-11  1.765452e-11
# pca_2         2.679757e-11 -1.627110e-11
# pca_3         1.197666e-11  1.347712e-10
# pca_4        -7.725115e-12  3.072013e-11
# pca_5        -3.294061e-12  8.955938e-11
# pca_6        -1.509088e-11 -1.568252e-11
# pca_7         4.801985e-11  2.206727e-11
# pca_8         1.000000e+00  5.290980e-11
# pca_9         5.290980e-11  1.000000e+00
#
# [25 rows x 25 columns]

# %% [markdown]
# - -1.0과 -0.7 사이이면, 강한 음적 선형관계
# - -0.7과 -0.3 사이이면, 뚜렷한 음적 선형관계
# - -0.3과 -0.1 사이이면, 약한 음적 선형관계
# - -0.1과 +0.1 사이이면, 거의 무시될 수 있는 선형관계
# - +0.1과 +0.3 사이이면, 약한 양적 선형관계
# - +0.3과 +0.7 사이이면, 뚜렷한 양적 선형관계
# - +0.7과 +1.0 사이이면, 강한 양적 선형관계

# %%
import seaborn as sns  

plt.figure(figsize=(15,15))
sns.heatmap(data = df.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')

# %%
# Check what affects the most for the yield stress
yield_corr = corr_matrix["yield stress"].sort_values(ascending=False)

for key in yield_corr.keys():
    print(key, ":", yield_corr[key])
# Out:
# yield stress : 1.0
# ica_2 : 0.568702788773061
# ica_3 : 0.028072050998610015
# ica_5 : 0.014939176066662495
# pca_9 : 0.0004491579620978134
# pca_3 : 0.00011084654802045581
# pca_5 : 3.036556604920631e-06
# pca_6 : 8.185339737867095e-08
# pca_8 : -7.555357146298705e-09
# pca_7 : -9.070329417414432e-08
# pca_4 : -1.2056057342548483e-06
# ica_8 : -0.01795598784711785
# ica_7 : -0.04138800224526907
# ica_6 : -0.06086291803432144
# 5k_IM : -0.08254804673206297
# ica_4 : -0.1840224130034384
# pca_2 : -0.2468286885007348
# 5k_RE : -0.441823369925482
# 5k_voltage : -0.5811107067374501
# 1k_IM : -0.7326888502982527
# ica_1 : -0.797472251274808
# elongation : -0.8868063822288432
# pca_1 : -0.969059020131521
# 1k_RE : -0.980479669847717
# 1k_voltage : -0.9946570634639302

# %%
elong_corr = corr_matrix["elongation"].sort_values(ascending=False)
# Out:
# elongation      1.000000e+00
# pca_1           9.343344e-01
# 1k_voltage      8.977971e-01
# 1k_RE           8.832472e-01
# ica_1           8.687207e-01
# 1k_IM           5.919424e-01
# 5k_voltage      2.944989e-01
# 5k_RE           2.900375e-01
# ica_6           1.462408e-01
# ica_7           6.555895e-02
# 5k_IM           5.342175e-02
# ica_8           2.903598e-02
# pca_4           1.228615e-03
# pca_5           9.821799e-04
# pca_8           7.181594e-07
# pca_7          -4.130112e-06
# pca_6          -8.746758e-06
# ica_5          -1.411064e-02
# ica_3          -3.387105e-02
# pca_2          -7.583040e-02
# pca_9          -1.403011e-01
# ica_4          -2.446810e-01
# pca_3          -3.187196e-01
# ica_2          -3.969657e-01
# yield stress   -8.868064e-01
# Name: elongation, dtype: float64

# %% [markdown]
# # 10 variables
# 29    0.007450  0.392201 -0.402959 -1.090197 -0.951224 -0.654380 -0.311484
# ..         ...       ...       ...       ...       ...       ...       ...
# 160  -0.370352 -0.037602 -1.088894  2.195395  0.286445 -0.690905  0.426706
# 161  -0.660943  0.756124  0.628583  0.840056 -0.178478 -0.230915  0.788883
# 162  -0.394869 -0.766498 -0.125129 -0.064951 -0.613213  0.034321  0.459255
# 163   0.045069  0.182779  0.922492  0.333110 -0.220430 -0.331287 -0.062565
# 164  -0.409041 -0.548342 -0.077421 -0.742994 -2.109714  0.345444  0.473109
# 165   0.066800  4.263185  1.337399  1.634862 -0.270656 -0.004057 -0.083394
# 166  -0.008047  0.397802 -0.520768 -0.612701 -0.459489 -0.142210 -0.018301
# 167   0.551912  0.798227  0.031032  1.351203  0.100781 -0.581423 -0.684461
# 168   0.131523 -0.195162  0.230460  1.045507 -0.064666 -0.401416 -0.184716
# 169   0.076035  0.444866  0.965033  0.172782 -0.046699 -0.029387 -0.111919
# 170  -0.295007 -1.224749  0.331267  1.103823  0.457651 -0.527781  0.319159
# 171   0.627413 -0.418105 -0.013225  0.034002  0.466200 -1.106652 -0.796987
# 172  -0.348580 -0.953486  0.934002  0.452797 -1.410516  0.156238  0.380065
# 173  -0.192582 -0.777106  1.699558 -0.478455 -1.862810  1.186011  0.197557
# 174   0.255416  0.301377  0.238796 -0.150875 -0.279340 -0.462568 -0.342848
# 175   0.289947 -0.934339  0.962487 -0.202102 -0.473702 -0.576499 -0.388923
# 176   0.558288 -1.120417  0.262914  0.397815  0.286549 -0.935602 -0.732380
# 177   0.112255 -1.120316 -1.460791  0.298204 -0.553670 -1.685948 -0.201716
# 178  -0.395685 -1.599569  1.047684 -0.953603 -0.491122 -1.203400  0.419914
# 179   0.209280 -0.701889 -0.742286  0.446403 -0.747901 -0.470758 -0.310187
# 180   0.145571  0.945547 -0.115494 -0.753139 -1.075432 -0.462832 -0.223491
# 181   0.409103 -0.285597 -0.957129  0.142349  0.082546 -1.596975 -0.551845
# 182   0.166970  0.268318  1.107639  0.859038 -1.295479  0.687315 -0.264728
# 183  -0.166085  0.182900 -0.908522 -0.375932 -0.622033 -0.540881  0.128967
# 184   0.909772  0.400387  0.581497  0.862960 -0.544972 -0.249471 -1.155262
# 185   0.810141  1.292746 -0.198534 -2.391419 -0.379395 -1.110941 -1.034209
# 186   0.439550 -0.041533 -0.392786 -1.877592 -0.295632 -1.051999 -0.597313
# 187   0.800474 -0.140165  0.389409  1.560220 -1.178133 -0.131090 -1.030405
# 188  -0.102707 -2.402913  2.426449  0.254092 -0.382208 -0.864356  0.028892
# 189   0.406597 -0.069889  0.947352 -0.308984 -2.498036  0.993733 -0.575524
#
# [190 rows x 25 columns]

# %%
# train, test data split
from sklearn.model_selection import train_test_split

X = df.loc[:,["1k_RE","1k_IM", "1k_voltage", "5k_RE", "5k_voltage", "pca_1", "pca_2", "ica_1","ica_2"]]
ys = df.loc[:,"yield stress"]
elong = df.loc[:,"elongation"]

X_train, X_test, ys_train, ys_test = train_test_split(X, ys, test_size=0.2)
X_train, X_test, el_train, el_test = train_test_split(X, elong, test_size=0.2)
len(X_train)
# Out:
# 152

# %%
# train, test data split of pca & ica
from sklearn.model_selection import train_test_split

X = df.loc[:,["1k_RE","1k_IM", "1k_voltage", "5k_RE", "5k_voltage", "5k_IM"]]
ys = df.loc[:,"yield stress"]
elong = df.loc[:,"elongation"]

X_train, X_test, ys_train, ys_test = train_test_split(X, ys, test_size=0.2)
X_train, X_test, el_train, el_test = train_test_split(X, elong, test_size=0.2)
len(X_train)
# Out:
# 152

# %%
len(X_test)
# Out:
# 38

# %%
X_train.shape
# Out:
# (152, 6)

# %%
X_train
# Out:
#         1k_RE     1k_IM  1k_voltage     5k_RE  5k_voltage     5k_IM
# 110  7.148297 -1.056941    2.188365  8.059805    5.309101  0.134880
# 166  7.097545 -1.114510    2.176707  8.067498    5.313490  0.015088
# 44   7.262192 -0.871048    2.219713  8.084806    5.313384  0.028430
# 22   7.301098 -0.798163    2.232501  8.106312    5.317891 -0.020133
# 31   7.259413 -1.038934    2.228250  8.088805    5.314041  0.109319
# 72   7.210297 -0.939787    2.206291  8.056814    5.309539  0.081580
# 84   7.183315 -1.024722    2.197493  8.065206    5.308661  0.104432
# 76   7.221163 -0.808060    2.203891  8.066271    5.309615  0.082328
# 30   7.278417 -0.911484    2.228685  8.077429    5.313206  0.116763
# 56   7.214248 -1.096842    2.214714  8.091798    5.312570  0.197695
# 62   7.224675 -0.938560    2.211428  8.069200    5.311998  0.171657
# 57   7.216858 -0.935602    2.212598  8.085569    5.310145  0.047452
# 117  7.141808 -1.019309    2.186599  8.079513    5.307195  0.206251
# 171  7.094720 -1.088944    2.176842  8.071477    5.310807  0.084279
# 157  7.125413 -0.989765    2.178226  8.080378    5.315456  0.027136
# 155  7.110678 -1.063292    2.178088  8.087300    5.315163  0.045124
# 5    7.344526 -0.815595    2.248745  8.103104    5.330322  0.089639
# 170  7.092730 -1.076187    2.175199  8.087161    5.314901  0.181310
# 45   7.256242 -0.969331    2.219477  8.083032    5.310472  0.093603
# 28   7.284677 -0.885166    2.229991  8.078420    5.315520  0.113994
# 113  7.143588 -1.038205    2.187054  8.094928    5.309365 -0.060385
# 70   7.187779 -1.136475    2.207242  8.065812    5.307708  0.133115
# 43   7.249126 -0.890761    2.219615  8.087777    5.315593  0.090593
# 85   7.165440 -0.947042    2.197031  8.087128    5.308938  0.048769
# 48   7.230754 -0.972286    2.216906  8.064789    5.314188  0.013367
# 99   7.165844 -0.966347    2.191940  8.072870    5.309162  0.022637
# 3    7.345533 -0.862965    2.249833  8.103011    5.329095  0.153286
# 172  7.113511 -1.027019    2.176390  8.079541    5.316118  0.167764
# 109  7.147599 -1.058126    2.187657  8.072554    5.310254  0.075799
# 160  7.087531 -1.163459    2.177362  8.099301    5.315981  0.051615
# ..        ...       ...         ...       ...         ...       ...
# 97   7.162874 -1.008984    2.192669  8.107825    5.306868  0.034435
# 115  7.141690 -1.020169    2.186819  8.072226    5.308166  0.114468
# 68   7.197683 -1.094173    2.207006  8.085668    5.312209  0.101615
# 23   7.294056 -0.921451    2.232636  8.093050    5.319212 -0.035762
# 37   7.281512 -0.782862    2.224625  8.088158    5.311557 -0.010685
# 144  7.092721 -1.201262    2.181300  8.086071    5.312442  0.067635
# 122  7.143701 -0.988321    2.186695  8.073487    5.305934 -0.041316
# 67   7.233366 -0.740186    2.208893  8.082549    5.309900  0.052018
# 169  7.110258 -0.996560    2.176078  8.074628    5.313185  0.033129
# 159  7.119267 -1.061014    2.179247  8.069068    5.316812 -0.028846
# 52   7.245787 -0.916166    2.215279  8.076019    5.311370  0.011214
# 177  7.076378 -1.220670    2.176330  8.077981    5.315152  0.137008
# 125  7.131074 -1.066286    2.185879  8.062111    5.307519 -0.090383
# 146  7.091701 -1.194535    2.180933  8.078002    5.317389  0.095883
# 128  7.134817 -1.039134    2.185847  8.053031    5.309051  0.052793
# 86   7.192062 -0.948800    2.197409  8.055909    5.310005 -0.010522
# 53   7.245172 -0.849144    2.214709  8.069501    5.310984  0.001098
# 189  7.115931 -1.018101    2.173926  8.068514    5.314169  0.077092
# 1    7.330924 -0.934697    2.249186  8.084683    5.329357  0.057399
# 181  7.077364 -1.166665    2.175047  8.074965    5.313651  0.064866
# 80   7.174609 -0.998405    2.200066  8.070097    5.310379 -0.043642
# 183  7.079194 -1.157279    2.173205  8.072152    5.316157  0.035902
# 100  7.130577 -1.163829    2.191669  8.077106    5.310902 -0.000109
# 112  7.166697 -0.961635    2.187801  8.061712    5.309193  0.137205
# 130  7.136154 -0.959285    2.184737  8.070618    5.307638  0.047253
# 129  7.127348 -1.057862    2.185390  8.059025    5.308102 -0.143113
# 38   7.274650 -0.838035    2.222884  8.074716    5.313113  0.076589
# 11   7.324171 -0.828684    2.240656  8.093121    5.319400  0.181138
# 51   7.245305 -0.903072    2.215403  8.068984    5.312309  0.092698
# 185  7.091567 -1.080754    2.174771  8.045659    5.311251 -0.072490
#
# [152 rows x 6 columns]

# %%
# Feature Scaling => Standardization
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

data_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('std_scaler', StandardScaler()),
])
imputer = SimpleImputer(strategy="median")

X_train = imputer.fit_transform(X_train)
X_train_std = data_pipeline.fit_transform(X_train)

ys_train = np.array(ys_train)
ys_train =ys_train.reshape(-1, 1)
ys_train = imputer.fit_transform(ys_train)
ys_train_std = data_pipeline.fit_transform(ys_train)


el_train = np.array(el_train)
el_train =el_train.reshape(-1, 1)
el_train = imputer.fit_transform(el_train)
el_train_std = data_pipeline.fit_transform(el_train)

X_test = imputer.fit_transform(X_test)
X_test_std =data_pipeline.fit_transform(X_test)

ys_test = np.array(ys_test)
ys_test = ys_test.reshape(-1, 1)
ys_test = imputer.fit_transform(ys_test)
ys_test_std = data_pipeline.fit_transform(ys_test)

el_test = np.array(el_test)
el_test = el_test.reshape(-1, 1)
el_test = imputer.fit_transform(el_test)
el_test_std = data_pipeline.fit_transform(el_test)


#print(X_train_std)

ys_test_std
# Out:
# array([[ 1.20451104],
#        [ 1.24780227],
#        [ 0.52677366],
#        [-0.17385975],
#        [ 0.39560826],
#        [-1.74451944],
#        [-2.11032816],
#        [-1.69025064],
#        [ 0.8728661 ],
#        [ 0.68318176],
#        [ 0.50120669],
#        [ 0.31301706],
#        [-1.58798893],
#        [ 1.10455619],
#        [ 0.16493537],
#        [ 0.63699534],
#        [ 0.43662284],
#        [-0.15560221],
#        [-0.35878156],
#        [-0.70559729],
#        [-1.08510976],
#        [-1.31649814],
#        [ 1.01666267],
#        [ 0.34053471],
#        [-0.1179416 ],
#        [ 0.71827633],
#        [ 0.67133709],
#        [-1.53925396],
#        [-0.62359546],
#        [ 0.00440384],
#        [ 1.14010928],
#        [-0.1366698 ],
#        [-2.24669042],
#        [ 0.77487445],
#        [ 1.1503678 ],
#        [ 1.09467335],
#        [ 0.0548558 ],
#        [ 0.5385152 ]])

# %%
#np.savetxt("ys_train.csv", ys_train, delimiter=",")

# %%
X_train_std.shape
# Out:
# (152, 6)

# %%
ys_train.shape
# Out:
# (152, 1)

# %%
np.random.seed(42)

# %% [markdown]
# Select and train a random forest regression model
# ===

# %%
# Normal Random Forest

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
rf_reg = RandomForestRegressor(random_state=42)
rf_reg.fit(X_train_std, ys_train_std)
ys_predictions_rf= rf_reg.predict(X_train_std) * np.std(ys_train) + np.mean(ys_train)
rf_mse = mean_squared_error(ys_train, ys_predictions_rf)
rf_rmse = np.sqrt(rf_mse)
rf_rmse
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 1.476820928854318

# %%
#ys_predictions_rf= np.sort(ys_predictions_rf, axis=None)
ys_predictions_rf
# Out:
# array([320.64291202, 288.75160424, 350.38914767, 311.59164222,
#        376.83190627, 347.32664027, 331.24496958, 285.21932851,
#        349.93333462, 374.64823183, 355.15269247, 294.59024669,
#        375.06611149, 266.72913044, 298.29902155, 354.12198188,
#        288.78390233, 364.62096581, 322.25621351, 299.99134328,
#        282.60803418, 365.60765155, 357.49202564, 361.26185904,
#        366.29084069, 378.43339705, 262.62456377, 305.46336746,
#        354.08951279, 364.38935865, 289.45433074, 336.9517405 ,
#        378.4057831 , 294.82951723, 366.45365514, 306.88138589,
#        353.3448271 , 293.01443794, 331.4372589 , 370.30398165,
#        252.71927823, 268.7466451 , 325.67801488, 251.54117845,
#        313.37538432, 360.46118979, 358.62476918, 320.72919183,
#        352.76139012, 248.93256406, 346.92264134, 363.28193541,
#        347.014663  , 214.25306287, 355.41786981, 374.58903824,
#        336.76365633, 391.32373256, 306.34561186, 270.14423856,
#        361.73645912, 248.97714143, 307.65364818, 347.44905794,
#        383.99331148, 237.18156222, 282.98783281, 346.02163453,
#        332.01520461, 326.76258602, 334.69152651, 311.08334616,
#        370.33836298, 330.01633644, 315.50474666, 363.28110658,
#        346.08688369, 303.43006924, 327.43080469, 330.02974053,
#        398.71890954, 343.04873691, 322.90020902, 286.68059548,
#        308.47030448, 372.24173641, 385.12910907, 322.21402915,
#        359.58329502, 356.49832498, 207.72978218, 340.7712734 ,
#        324.3382123 , 386.25472966, 363.08471769, 376.18493134,
#        321.15170592, 308.12241103, 303.28483379, 229.51882603,
#        363.51511286, 337.8442774 , 321.23176453, 371.19323596,
#        380.0002481 , 345.90160985, 244.44825133, 260.58096855,
#        319.21171258, 377.51232705, 340.93235515, 285.54984964,
#        338.48564271, 380.97586974, 362.40587588, 351.14689152,
#        389.02291342, 322.65109052, 330.0907912 , 369.26331651,
#        302.48682414, 342.40727678, 314.30079525, 344.41782951,
#        355.0518875 , 244.93667432, 272.40787329, 387.27068377,
#        370.2618078 , 324.30044382, 284.81461911, 388.73168545,
#        395.78606483, 195.88606948, 334.91863509, 370.10280466,
#        366.41239034, 368.23690948, 342.97040688, 345.34986678,
#        363.72874906, 302.01743647, 328.50358386, 346.68293303,
#        391.61265961, 268.86301648, 333.06253128, 352.41939241,
#        261.91817783, 331.7629695 , 371.60833509, 343.46180105])

# %% [markdown]
# Hyper Parameters Tuning: GridSearch CV function
# ---

# %% [markdown]
# GridSearchCV implements a “fit” and a “score” method. It also implements “predict”, “predict_proba”, “decision_function”, “transform” and “inverse_transform” if they are implemented in the estimator used.
#
# The parameters of the estimator used to apply these methods are optimized by cross-validated grid-search over a parameter grid.

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    # try 12 (3×4) combinations of hyperparameters
    {'n_estimators': [5 ,10,20,35, 50,100], 'max_features': [0.6, 0.8, 1.0],
     'bootstrap': [True, False], 'random_state': [42], 'max_depth': [None, 10, 20, 30],
                      'min_samples_leaf':[1,3,5],'min_samples_split':[2, 4, 8],
                      
    }
  ]

rf_reg = RandomForestRegressor(random_state=42)
# train across 5 folds, that's a total of (12+6)*5=90 rounds of training 
grid_search = GridSearchCV(rf_reg, param_grid, cv=10,
                           scoring='neg_mean_squared_error',
                           return_train_score=True)
grid_search.fit(X_train_std, ys_train_std)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features=1.0, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=4,
#                       min_weight_fraction_leaf=0.0, n_estimators=50,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': None,
#  'max_features': 1.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'n_estimators': 50,
#  'random_state': 42}

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 0.12733357450354874 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# 0.11839375208407485 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}
# 0.09493223903214393 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}
# 0.09070238460971165 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}
# 0.09232506307568668 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}
# 0.08389179045932599 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 0.12512822703422283 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}
# 0.1218052475216079 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}
# 0.10046751221525671 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}
# 0.09464473729344484 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.09545193578259072 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.08742914740056446 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.1270004420485928 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.12194068524449331 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.10672474325456403 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.098658814636075 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.09984461884967213 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.09154365121225932 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}
# 0.1385681595343838 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# 0.12452603222000805 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}
# 0.10328082750855626 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}
# 0.09662595782149273 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}
# 0.10303643361918048 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}
# 0.09342482646024748 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 0.1385681595343838 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}
# 0.12452603222000805 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}
# 0.10328082750855626 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}
# 0.09662595782149273 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.10303643361918048 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.09342482646024748 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.13282140550321517 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.12848805147062917 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.11042560592198597 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.10279916688867898 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.1048014916237572 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.09522275732992852 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}
# 0.1400424013543615 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# 0.1451550802587372 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}
# 0.12038013066977771 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}
# 0.11349879153093936 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}
# 0.11927664604490375 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}
# 0.10872784693631309 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 0.1400424013543615 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}
# 0.1451550802587372 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}
# 0.12038013066977771 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}
# 0.11349879153093936 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.11927664604490375 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.10872784693631309 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.1400424013543615 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.1451550802587372 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.12038013066977771 {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0
{'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.09583516587030359 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.08764100444592797 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.1270004420485928 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.12194068524449331 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.10672474325456403 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.098728922828305 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.0998922796919689 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.09156674895050493 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}
# 0.1385681595343838 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# 0.12452603222000805 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}
# 0.10328082750855626 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}
# 0.09662595782149273 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}
# 0.10303643361918048 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}
# 0.09342482646024748 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 0.1385681595343838 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}
# 0.12452603222000805 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}
# 0.10328082750855626 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}
# 0.09662595782149273 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.10303643361918048 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.09342482646024748 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.13282140550321517 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.12848805147062917 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.11042560592198597 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.10279916688867898 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.1048014916237572 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.09522275732992852 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}
# 0.1400424013543615 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# 0.1451550802587372 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}
# 0.12038013066977771 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}
# 0.11349879153093936 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}
# 0.11927664604490375 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}
# 0.10872784693631309 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 0.1400424013543615 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}
# 0.1451550802587372 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}
# 0.12038013066977771 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}
# 0.11349879153093936 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.11927664604490375 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.10872784693631309 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.1400424013543615 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.1451550802587372 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.12038013066977771 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.11349879153093936 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.11927664604490375 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.10872784693631309 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.6, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}
# 0.08692183918435997 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# 0.09411240497179194 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}
# 0.08102288741961919 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}
# 0.07405960998114382 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}
# 0.07248378932677463 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}
# 0.0645303518073091 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 0.10534602543069109 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}
# 0.10113592429211032 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}
# 0.08222233743488891 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}
# 0.0719737070663559 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.07106819692992103 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.06695940430632553 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.11075715503192608 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.10194026438157498 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.08603965784763415 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.07866686719895798 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.0786041512391565 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.07261740458077524 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}
# 0.10931452396798351 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# 0.09126572644780485 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}
# 0.07416136802843924 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}
# 0.0697999763392612 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}
# 0.0704331076575736 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}
# 0.06795649854404928 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 0.10931452396798351 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}
# 0.09126572644780485 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}
# 0.07416136802843924 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}
# 0.0697999763392612 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.0704331076575736 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.06795649854404928 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.10671941430548863 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.10566325183896144 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.0864598446931056 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.07814313598924118 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.07791576647480154 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.07116593438032455 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}
# 0.11275844557578549 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# 0.1118459189936411 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}
# 0.0954689586456325 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}
# 0.08813920060690576 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}
# 0.08567683357499456 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}
# 0.08132412296024182 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 0.11275844557578549 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}
# 0.1118459189936411 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}
# 0.0954689586456325 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}
# 0.08813920060690576 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.08567683357499456 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.08132412296024182 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.11275844557578549 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.1118459189936411 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.0954689586456325 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.08813920060690576 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.08567683357499456 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.08132412296024182 {'bootstrap': True, 'max_depth': 10, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}
# 0.06508095149403527 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# 0.05989455294014317 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}
# 0.056468741171839545 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}
# 0.05734164490453229 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}
# 0.055693759286455695 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}
# 0.05461511611674175 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 0.05711750997386141 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}
# 0.05447131954563505 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}
# 0.054523278381381136 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}
# 0.05291892594478588 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.05263656372483473 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.05313537931938809 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.07068490173311806 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.06570929494147885 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.0604422145363404 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.058502608944423676 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.05533614722191623 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.05642727265242418 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}
# 0.06669754340736384 {'bootstrap': True, 'max_depth': 10, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# ...
# 0.10319117914836391 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.09062254201646015 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.0828770348195007 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.08299239224725172 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.08324435389551739 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.07774971209433727 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}
# 0.09614345723303876 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# 0.08593688168141307 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}
# 0.07653650959033233 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}
# 0.075312923687634 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}
# 0.07441690878319854 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}
# 0.07043957639657807 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 0.09614345723303876 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}
# 0.08593688168141307 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}
# 0.07653650959033233 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}
# 0.075312923687634 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.07441690878319854 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.07043957639657807 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.09582662606192922 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.0886738399681379 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.08330971213154373 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.08416229846202714 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.08402289609901044 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.07800146016455013 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}
# 0.10046283240165532 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# 0.09123108826084866 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}
# 0.08216398100178829 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}
# 0.08025791896031635 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}
# 0.0824072107972461 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}
# 0.07827035689111357 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 0.10046283240165532 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}
# 0.09123108826084866 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}
# 0.08216398100178829 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}
# 0.08025791896031635 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.0824072107972461 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.07827035689111357 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.10046283240165532 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.09123108826084866 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.08216398100178829 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.08025791896031635 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.0824072107972461 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.07827035689111357 {'bootstrap': False, 'max_depth': 30, 'max_features': 0.8, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}
# 0.07462835551836546 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# 0.07225307411165 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}
# 0.07014211553626319 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}
# 0.07228540474860416 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}
# 0.07072299123583312 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}
# 0.06961602437891937 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 0.07296738831147741 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}
# 0.07580825923401538 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}
# 0.07231913115856123 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}
# 0.0723789994225424 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.07237302184076023 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.0722617035010561 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.08726335226747087 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.08770657877246586 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.08789164642326394 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.08712268899948314 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.08743214560672047 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.08766877626816433 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}
# 0.06881722517246269 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# 0.07155447095423315 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}
# 0.0724135522834026 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}
# 0.0717815088231303 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}
# 0.07181463413714105 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}
# 0.07365654249020517 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 0.06881722517246269 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}
# 0.07155447095423315 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}
# 0.0724135522834026 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}
# 0.0717815088231303 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.07181463413714105 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.07365654249020517 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.08538902275463342 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.08497115205151001 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.08602052372190346 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.08662851419077439 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.08705962452791272 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.08694554921241011 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}
# 0.08927197949312435 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}
# 0.08814337034752669 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}
# 0.0893185096841767 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}
# 0.08914602471522864 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}
# 0.08853260301418137 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}
# 0.0886647196048133 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}
# 0.08927197949312435 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}
# 0.08814337034752669 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}
# 0.0893185096841767 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}
# 0.08914602471522864 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}
# 0.08853260301418137 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}
# 0.0886647196048133 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}
# 0.08927197949312435 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}
# 0.08814337034752669 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}
# 0.0893185096841767 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}
# 0.08914602471522864 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}
# 0.08853260301418137 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}
# 0.0886647196048133 {'bootstrap': False, 'max_depth': 30, 'max_features': 1.0, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}

# %%
ys_rf_final_model = grid_search.best_estimator_

# %%
"""
ys_rf_final_model = RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
                      max_features=1.0, max_leaf_nodes=None,
                      min_impurity_decrease=0.0, min_impurity_split=None,
                      min_samples_leaf=1, min_samples_split=2,
                      min_weight_fraction_leaf=0.0, n_estimators=100,
                      n_jobs=None, oob_score=False, random_state=42, verbose=0,
                      warm_start=False)
                   
ys_rf_final_model.fit(X_train_std, ys_train_std)
   """
# Out:
# "\nys_rf_final_model = RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,\n                      max_features=1.0, max_leaf_nodes=None,\n                      min_impurity_decrease=0.0, min_impurity_split=None,\n                      min_samples_leaf=1, min_samples_split=2,\n                      min_weight_fraction_leaf=0.0, n_estimators=100,\n                      n_jobs=None, oob_score=False, random_state=42, verbose=0,\n                      warm_start=False)\n                   \nys_rf_final_model.fit(X_train_std, ys_train_std)\n   "

# %%
# Feature importance

rf_feature_importance = ys_rf_final_model.feature_importances_
print("feature importances\n")
print("1kHz_voltage: ",rf_feature_importance[0])
print("1kHz_Re: ",rf_feature_importance[1])
print("1kHz_Im: ",rf_feature_importance[2])
print("5kHz_voltage : ",rf_feature_importance[3])
print("5kHz_Re: ",rf_feature_importance[4])
print("5kHz_Im: ",rf_feature_importance[5])
# Out:
# feature importances
#
# 1kHz_voltage:  0.8719619367087198
# 1kHz_Re:  0.12314361909636615
# 1kHz_Im:  0.0003424840110623366
# 5kHz_voltage :  0.003986361703396311
# 5kHz_Re:  0.000334903157233666
# 5kHz_Im:  0.0002306953232218003

# %%
X_test_std = np.array(X_test_std)
#X_test_std= X_test_std.reshape(-1, 1)
#X_test_std

# %%
ys_rf_train_predictions = ys_rf_final_model.predict(X_train_std) * np.std(ys_train) + np.mean(ys_train)
ys_rf_train_mse = mean_squared_error(ys_train, ys_rf_train_predictions)
ys_rf_train_rmse = np.sqrt(ys_rf_train_mse)
ys_rf_train_rmse
# Out:
# 1.2356477943345479

# %%
ys_rf_test_predictions = ys_rf_final_model.predict(X_test_std) * np.std(ys_test) + np.mean(ys_test)
ys_rf_test_mse = mean_squared_error(ys_test,ys_rf_test_predictions)
ys_rf_test_rmse = np.sqrt(ys_rf_test_mse)
ys_rf_test_rmse
# Out:
# 3.1826864846358216

# %% [markdown]
# ## Central Limit Theorem

# %%
print(cvres['mean_train_score'].shape)
print('Combinations')
# Out:
# (1296,)
# Combinations

# %%
mean_test_score =cvres['mean_test_score']
print(mean_test_score)
# Out:
# [-0.01621384 -0.01401708 -0.00901213 ... -0.00794701 -0.00783802
#  -0.00786143]

# %%
mean_train_score =cvres['mean_train_score']
print(mean_train_score)
# Out:
# [-0.00428722 -0.0027882  -0.00144841 ... -0.00358447 -0.00358439
#  -0.00358408]

# %%
std_test_score =cvres['std_test_score']
print(std_test_score)
# Out:
# [0.00648155 0.00609073 0.00288895 ... 0.00519272 0.00504423 0.0050544 ]

# %%
std_train_score =cvres['std_train_score']
print(std_test_score)
# Out:
# [0.00648155 0.00609073 0.00288895 ... 0.00519272 0.00504423 0.0050544 ]

# %%
  # !ls /content/gdrive
# Out:
# 'My Drive'

# %%
with open('/content/gdrive/My Drive/validation/cvscores/Random_Forest/yield_stress/RF_6V.txt', 'w') as f:
  for key in cvres.keys():
    f.write("\n")
    f.write(key)
    f.write(": ")
    f.write(np.str(cvres[key]))
    f.write("\n")


# !cat /content/gdrive/My\ Drive/validation/cvscores/Random_Forest/yield_stress/RF_2V.txt
# Out:
# mean_fit_time: [0.00513186 0.00899426 0.01760196 ... 0.03133538 0.04511828 0.09055208]
#
# std_fit_time: [0.00078297 0.00060235 0.0022649  ... 0.0017932  0.00303316 0.00599404]
#
# mean_score_time: [0.00111564 0.00148849 0.00216752 ... 0.00325178 0.00442339 0.00837466]
#
# std_score_time: [0.00018915 0.00055985 0.00037417 ... 0.00043297 0.00078891 0.00137793]
#
# param_bootstrap: [True True True ... False False False]
#
# param_max_depth: [None None None ... 30 30 30]
#
# param_max_features: [0.6 0.6 0.6 ... 1.0 1.0 1.0]
#
# param_min_samples_leaf: [1 1 1 ... 5 5 5]
#
# param_min_samples_split: [2 2 2 ... 8 8 8]
#
# param_n_estimators: [5 10 20 ... 35 50 100]
#
# param_random_state: [42 42 42 ... 42 42 42]
#
# params: [{'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 35, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 5, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 10, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 20, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 35, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 50, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 5, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 10, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 35, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 50, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 5, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 10, 'random_state': 42}, {'bootstrap': True, 'max_depth': None, 'max_features': 0.6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 20, 'random_state': 4 ...
#
# split0_test_score: [-0.00367504 -0.00290337 -0.00171153 ... -0.00151757 -0.00151757
#  -0.00151757]
#
# split1_test_score: [-0.01422995 -0.01168687 -0.01166297 ... -0.0069356  -0.00695265
#  -0.00695265]
#
# split2_test_score: [-0.01019934 -0.01076424 -0.01007399 ... -0.01886266 -0.01886266
#  -0.01886266]
#
# split3_test_score: [-0.01084946 -0.00611957 -0.01678206 ... -0.0021691  -0.00218464
#  -0.00230123]
#
# split4_test_score: [-0.04631369 -0.12356192 -0.2897195  ... -0.06049401 -0.06052307
#  -0.0604892 ]
#
# split5_test_score: [-0.00295759 -0.00323145 -0.003684   ... -0.0018217  -0.0018217
#  -0.0018217 ]
#
# split6_test_score: [-0.00873569 -0.00828455 -0.03509465 ... -0.00164543 -0.00164543
#  -0.00164543]
#
# split7_test_score: [-0.10359533 -0.30747699 -0.12602698 ... -0.17454391 -0.18462961
#  -0.18794043]
#
# split8_test_score: [-0.00503057 -0.15226029 -0.20520925 ... -0.16859078 -0.16859078
#  -0.16859078]
#
# split9_test_score: [-0.01897307 -0.00993462 -0.00727232 ... -0.00176702 -0.00176702
#  -0.00176702]
#
# split10_test_score: [-1.46139602 -1.41972761 -1.22762179 ... -1.08529348 -1.08529348
#  -1.08529348]
#
# split11_test_score: [-0.00456199 -0.00374729 -0.00284228 ... -0.00351117 -0.00351117
#  -0.00351117]
#
# split12_test_score: [-0.0028023  -0.01159033 -0.00390443 ... -0.00611554 -0.00679703
#  -0.00759026]
#
# split13_test_score: [-0.01251391 -0.00465742 -0.0058565  ... -0.00113014 -0.00113014
#  -0.00113014]
#
# split14_test_score: [-0.01765944 -0.01688624 -0.00983115 ... -0.00645909 -0.00612872
#  -0.00628091]
#
# split15_test_score: [-0.00327276 -0.02809266 -0.00620156 ... -0.00093066 -0.00093066
#  -0.00093066]
#
# split16_test_score: [-0.02024656 -0.00120958 -0.0023136  ... -0.00636612 -0.00636612
#  -0.00636612]
#
# split17_test_score: [-0.22547868 -0.11846954 -0.10671608 ... -0.13479794 -0.13479794
#  -0.13479794]
#
# split18_test_score: [-0.00237954 -0.00274961 -0.00168422 ... -0.00666804 -0.00666804
#  -0.00666804]
#
# split19_test_score: [-0.00515848 -0.00477501 -0.01001302 ... -0.01388875 -0.01388875
#  -0.01388875]
#
# split20_test_score: [-0.11672956 -0.02305172 -0.02934116 ... -0.00477419 -0.00477419
#  -0.00477419]
#
# split21_test_score: [-0.00187206 -0.00657845 -0.00283419 ... -0.03713174 -0.03713174
#  -0.03713174]
#
# split22_test_score: [-0.04834568 -0.09826539 -0.03069915 ... -0.00425082 -0.00425082
#  -0.00425082]
#
# split23_test_score: [-0.03451694 -0.02784041 -0.0136976  ... -0.00371715 -0.00371715
#  -0.00371715]
#
# split24_test_score: [-0.01038675 -0.01303497 -0.00377608 ... -0.01101411 -0.0117017
#  -0.01212296]
#
# split25_test_score: [-0.00881617 -0.00408923 -0.00324636 ... -0.00181681 -0.00181681
#  -0.00181681]
#
# split26_test_score: [-0.19413634 -0.19718354 -0.22876751 ... -0.77175538 -0.77175538
#  -0.77175538]
#
# split27_test_score: [-0.00828972 -0.00417224 -0.00421405 ... -0.00236253 -0.00236253
#  -0.00236253]
#
# split28_test_score: [-0.00546776 -0.00467478 -0.00496027 ... -0.00440045 -0.00428424
#  -0.00432589]
#
# split29_test_score: [-0.01401105 -0.01338159 -0.01080556 ... -0.02176308 -0.02176308
#  -0.02176308]
#
# mean_test_score: [-0.07980863 -0.0869513  -0.07958022 ... -0.08447979 -0.08484404
#  -0.085002  ]
#
# std_test_score: [0.2605027  0.2555237  0.22393885 ... 0.23227176 0.23239711 0.23242811]
#
# rank_test_score: [555 805 552 ... 706 721 739]
#
# split0_train_score: [-0.02717893 -0.01143346 -0.01188027 ... -0.04085523 -0.04085523
#  -0.04085523]
#
# split1_train_score: [-0.02698104 -0.01224865 -0.01100538 ... -0.04077431 -0.04077431
#  -0.04077431]
#
# split2_train_score: [-0.02492354 -0.01916468 -0.01338663 ... -0.04022881 -0.04022881
#  -0.04022881]
#
# split3_train_score: [-0.02023747 -0.01706745 -0.01163564 ... -0.04054281 -0.04054281
#  -0.04054281]
#
# split4_train_score: [-0.02159786 -0.01767546 -0.01609396 ... -0.04480059 -0.04480059
#  -0.04480059]
#
# split5_train_score: [-0.01891879 -0.01689849 -0.01630067 ... -0.04074992 -0.04074992
#  -0.04074992]
#
# split6_train_score: [-0.01844049 -0.01782534 -0.01463018 ... -0.04066366 -0.04066366
#  -0.04066366]
#
# split7_train_score: [-0.01444083 -0.01667082 -0.01248206 ... -0.05761324 -0.05761324
#  -0.05761324]
#
# split8_train_score: [-0.0174799  -0.01231297 -0.01221229 ... -0.04170176 -0.04170176
#  -0.04170176]
#
# split9_train_score: [-0.02011361 -0.01719453 -0.01400311 ... -0.04063654 -0.04063654
#  -0.04063654]
#
# split10_train_score: [-0.01297513 -0.01312945 -0.0083107  ... -0.01660291 -0.01660291
#  -0.01660291]
#
# split11_train_score: [-0.02021727 -0.01270702 -0.00662678 ... -0.04050387 -0.04050387
#  -0.04050387]
#
# split12_train_score: [-0.0240013  -0.01607345 -0.00951019 ... -0.04050749 -0.04050749
#  -0.04050749]
#
# split13_train_score: [-0.02171182 -0.01259449 -0.00882099 ... -0.04070455 -0.04070455
#  -0.04070455]
#
# split14_train_score: [-0.02840143 -0.01513639 -0.01023488 ... -0.04062215 -0.04062215
#  -0.04062215]
#
# split15_train_score: [-0.01954228 -0.01064583 -0.00890143 ... -0.04070001 -0.04070001
#  -0.04070001]
#
# split16_train_score: [-0.02670324 -0.01705837 -0.00824976 ... -0.04061546 -0.04061546
#  -0.04061546]
#
# split17_train_score: [-0.01217503 -0.00942462 -0.00491529 ... -0.04265909 -0.04265909
#  -0.04265909]
#
# split18_train_score: [-0.01726038 -0.01171253 -0.00625619 ... -0.04038531 -0.04038531
#  -0.04038531]
#
# split19_train_score: [-0.01948576 -0.01535056 -0.00832733 ... -0.04026424 -0.04026424
#  -0.04026424]
#
# split20_train_score: [-0.01427158 -0.01540642 -0.00818924 ... -0.04057063 -0.04057063
#  -0.04057063]
#
# split21_train_score: [-0.01927439 -0.01551063 -0.00881479 ... -0.04027201 -0.04027201
#  -0.04027201]
#
# split22_train_score: [-0.02456951 -0.01954573 -0.01044798 ... -0.04070661 -0.04070661
#  -0.04070661]
#
# split23_train_score: [-0.02532166 -0.01804343 -0.01065909 ... -0.04047561 -0.04047561
#  -0.04047561]
#
# split24_train_score: [-0.03225013 -0.01841336 -0.01005063 ... -0.04085336 -0.04085336
#  -0.04085336]
#
# split25_train_score: [-0.0248245  -0.01820752 -0.00875633 ... -0.04070005 -0.04070005
#  -0.04070005]
#
# split26_train_score: [-0.00535382 -0.008777   -0.00665064 ... -0.04098436 -0.04098436
#  -0.04098436]
#
# split27_train_score: [-0.0172671  -0.00919844 -0.00560143 ... -0.04060222 -0.04060222
#  -0.04060222]
#
# split28_train_score: [-0.00575077 -0.00660553 -0.00416032 ... -0.04091177 -0.04091177
#  -0.04091177]
#
# split29_train_score: [-0.01473333 -0.00879833 -0.00466594 ... -0.0403076  -0.0403076
#  -0.0403076 ]
#
# mean_train_score: [-0.0198801  -0.01436103 -0.009726   ... -0.0406172  -0.0406172
#  -0.0406172 ]
#
# std_train_score: [0.00613532 0.00354853 0.00318661 ... 0.00544489 0.00544489 0.00544489]

# %% [markdown]
# Train data plotting
# ---

# %%
# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "BestHyperParameter/RF_Regression/yield_stress_6V"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

# %%
# Difference of train data
xx = np.linspace(0,len(X_train),len(X_train))
plt.figure
plt.grid()
ys_train_sort = np.sort(ys_train, axis=None)
ys_rf_train_predictions_sort= np.sort(ys_rf_train_predictions, axis=None)
plt.plot(xx,ys_train_sort,"b-", xx, ys_rf_train_predictions_sort,"r--")
plt.title("Train data vs Train Prediction(RF) Param Fitted")
plt.xlabel("Order of data")
plt.ylabel("Yield Stress")
save_fig("TrainPrediction_with_6V_RF_ParamFitted")
# Out:
# Saving figure TrainPrediction_with_6V_RF_ParamFitted

# %%
# Difference of train data
difference = ys_train_sort - ys_rf_train_predictions_sort

xx = np.linspace(0,len(difference),len(difference))
y = np.zeros((len(difference),1))
#y.reshape(1,len(difference))
plt.figure
plt.grid()
plt.plot(xx,y,"b-", xx, difference,"r--")
plt.title("Difference between Train data vs Prediction(RF) Param Fitted")
#plt.ylim(-30, 30)
plt.xlabel("Order of data")
plt.ylabel("Yield Stress")

save_fig("Difference_between_Train_data_vs_Prediction_6V_RF_ParamFitted")
# Out:
# Saving figure Difference_between_Train_data_vs_Prediction_6V_RF_ParamFitted

# %% [markdown]
# Test data plotting
# ---

# %%
# Difference of train data
xx = np.linspace(0,len(X_test),len(X_test))
plt.figure
plt.grid()
ys_test_sort = np.sort(ys_test, axis=None)
ys_rf_test_predictions_sort= np.sort(ys_rf_test_predictions, axis=None)
plt.plot(xx,ys_test_sort,"b-", xx, ys_rf_test_predictions_sort,"r--")
plt.title("Test data vs Test Prediction(RF) Param Fitted")
plt.xlabel("Order of data")
plt.ylabel("Yield Stress")
save_fig("TestPrediction_with_6V_RF_ParamFitted")
# Out:
# Saving figure TestPrediction_with_6V_RF_ParamFitted

# %%
# Difference of train data
difference = ys_test_sort - ys_rf_test_predictions_sort

xx = np.linspace(0,len(difference),len(difference))
y = np.zeros((len(difference),1))
#y.reshape(1,len(difference))
plt.figure
plt.grid()
plt.plot(xx,y,"b-", xx, difference,"r--")
plt.title("Difference between Test data vs Prediction(RF) Param Fitted")
#plt.ylim(-30, 30)
plt.xlabel("Order of data")
plt.ylabel("Yield Stress")

save_fig("Difference_between_Test_data_vs_Prediction_6V_RF_ParamFitted")
# Out:
# Saving figure Difference_between_Test_data_vs_Prediction_6V_RF_ParamFitted

# %% [markdown]
# ## Extracting files

# %%
# !ls images/BestHyperParameter/RF_Regression/yield_stress_6V/
# Out:
# Difference_between_Test_data_vs_Prediction_6V_RF_ParamFitted.png
# Difference_between_Train_data_vs_Prediction_6V_RF_ParamFitted.png
# TestPrediction_with_6V_RF_ParamFitted.png
# TrainPrediction_with_6V_RF_ParamFitted.png

# %%
from google.colab import files
# Upload local files to Colab VM
#uploaded = files.upload()
# Download Colab VM files to local
files.download('images/BestHyperParameter/RF_Regression/yield_stress_6V/TrainPrediction_with_6V_RF_ParamFitted.png')

# %%
files.download('images/BestHyperParameter/RF_Regression/yield_stress_6V/TestPrediction_with_6V_RF_ParamFitted.png')

# %%
files.download('images/BestHyperParameter/RF_Regression/yield_stress_6V/Difference_between_Train_data_vs_Prediction_6V_RF_ParamFitted.png')

# %%
files.download('images/BestHyperParameter/RF_Regression/yield_stress_6V/Difference_between_Test_data_vs_Prediction_6V_RF_ParamFitted.png')

# %%
files.download('/content/gdrive/My Drive/validation/cvscores/Random_Forest/yield_stress/RF_6V.txt')

# %% [markdown]
# #### elongation
